# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd

# %%
def get_data(from_, to_):
    key = "WRvGBkn9UEtw%2BAsg0tYo210Etxvb1QEcAX%2BwfWvOxVGYJkh1CNZ%2FY4QFa0r7j4bhT4NjPu7z1i1ck8ZgsKMt2Q%3D%3D"
    url = "http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson?serviceKey={}&pageNo=1&numOfRows=10&startCreateDt={}&endCreateDt={}"
    r = requests.get(url.format(key, from_, to_))
    root = ET.fromstring(r.text)
    total = []
    items = root.iter(tag='item')
    for element in items:
        #print(element.find("accDefRate").text)
        covid_dict = {}
        for x in element:
            covid_dict[x.tag] = x.text
        total.append(covid_dict)

    result = pd.DataFrame(total)[['decideCnt', 'stateDt']]
    return result.decideCnt, list(map(str, pd.to_datetime(result.stateDt)))

# %%
decideCnt, stateDt = get_data('20210101', '20211017')

# %%
decideCnt, stateDt
# Out:
# (0      342396
#  1      340976
#  2      339359
#  3      337677
#  4      335740
#          ...
#  284     64964
#  285     64250
#  286     63230
#  287     62573
#  288     61753
#  Name: decideCnt, Length: 289, dtype: object,
#  ['2021-10-17 00:00:00',
#   '2021-10-16 00:00:00',
#   '2021-10-15 00:00:00',
#   '2021-10-14 00:00:00',
#   '2021-10-13 00:00:00',
#   '2021-10-12 00:00:00',
#   '2021-10-11 00:00:00',
#   '2021-10-10 00:00:00',
#   '2021-10-08 00:00:00',
#   '2021-10-07 00:00:00',
#   '2021-10-06 00:00:00',
#   '2021-10-05 00:00:00',
#   '2021-10-04 00:00:00',
#   '2021-10-03 00:00:00',
#   '2021-10-02 00:00:00',
#   '2021-10-01 00:00:00',
#   '2021-09-30 00:00:00',
#   '2021-09-29 00:00:00',
#   '2021-09-28 00:00:00',
#   '2021-09-27 00:00:00',
#   '2021-09-26 00:00:00',
#   '2021-09-25 00:00:00',
#   '2021-09-24 00:00:00',
#   '2021-09-23 00:00:00',
#   '2021-09-22 00:00:00',
#   '2021-09-21 00:00:00',
#   '2021-09-20 00:00:00',
#   '2021-09-19 00:00:00',
# ...

# %%
[''.join(str(format(int(x), ',')), str(y))for x, y in zip(decideCnt, stateDt)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-a991973b95a7> in <module>
# ----> 1 [''.join(str(format(int(x), ',')), str(y))for x, y in zip(decideCnt, stateDt)]
#
# <ipython-input-23-a991973b95a7> in <listcomp>(.0)
# ----> 1 [''.join(str(format(int(x), ',')), str(y))for x, y in zip(decideCnt, stateDt)]
#
# TypeError: join() takes exactly one argument (2 given)

# %%
[str(format(int(x), ',')) for x in decideCnt]
# Out:
# ['342,396',
#  '340,976',
#  '339,359',
#  '337,677',
#  '335,740',
#  '334,156',
#  '332,810',
#  '331,513',
#  '327,966',
#  '325,791',
#  '323,366',
#  '321,339',
#  '319,765',
#  '318,095',
#  '316,010',
#  '313,766',
#  '311,282',
#  '308,719',
#  '305,838',
#  '303,549',
#  '301,167',
#  '298,398',
#  '295,127',
#  '292,698',
#  '290,983',
#  '289,263',
#  '287,534',
#  '285,930',
#  '284,021',
#  '281,934',
#  '279,926',
#  '277,984',
#  '275,908',
#  '274,411',
#  '272,978',
#  '271,223',
#  '269,360',
#  '267,467',
#  '265,418',
#  '263,370',
#  '261,773',
#  '260,398',
#  '258,908',
#  '257,105',
#  '255,397',
#  '253,437',
#  '251,415',
#  '250,045',
#  '248,560',
#  '246,941',
#  '245,150',
#  '243,313',
#  '241,431',
#  '239,277',
#  '237,770',
#  '236,353',
#  '234,727',
#  '232,850',
#  '230,800',
#  '228,648',
#  '226,845',
#  '225,473',
#  '223,918',
#  '222,102',
#  '220,174',
#  '218,185',
#  '216,198',
#  '213,977',
#  '212,440',
#  '210,949',
#  '209,221',
# ...
