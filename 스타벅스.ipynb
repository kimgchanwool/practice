# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = 'https://www.starbucks.co.kr/store/store_map.do'
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36"}

total = []
r = requests.get(url, headers=headers)
#total.append(pd.read_html(r.text)[0])

# %%
import json      # 텍스트로 된 json 형태의 데이터를 파이썬의 딕셔너리 형태로 변환
from pandas.io.json import json_normalize

# %%
target_url = 'https://www.starbucks.co.kr/store/store_map.do'
p_sido_cd = '01'
p_gugun_cd = '0101'
request = requests.post(target_url,
                        data={
                            'ins_lat': 37.5108295,  # 위도
                            'ins_lng': 127.02928809999999,  # 경도
                            'p_sido_cd': p_sido_cd,
                            'p_gugun_cd': p_gugun_cd,
                            'in_biz_cd': '',
                            'iend': 1500,  # 서버에서 얻어오는 최대 매장의 개수
                            'set_date': ''
                        })
json.load(request.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-f5a4336167d8> in <module>
#      12                             'set_date': ''
#      13                         })
# ---> 14 json.load(request.text)
#
# ~\anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'

# %%
request.text
# Out:
# '\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n\t<head>\r\n\t\t\r\n\r\n\n\n\n\n\n\n\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta charset="utf-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\r\n<meta property="og:type"\t\tcontent="website">\r\n<meta property="og:title"\t\tcontent="Starbucks">\r\n<meta property="og:url"\t\t\tcontent="https://www.starbucks.co.kr/">\r\n<meta property="og:image"\t\tcontent="https://image.istarbucks.co.kr/common/img/kakaotalk.png">\r\n<meta property="og:description" content="Starbucks">\r\n\r\n<title id="titleJoin">Starbucks Coffee Korea</title>\r\n<link rel="shortcut icon" href="https://image.istarbucks.co.kr/common/img/common/favicon.ico?v=200828" type="image/ico"> <!-- 20200827 파비콘 교체 및 CDN 변수처리 -->\r\n<link href="/common/css/reset.css" rel="stylesheet">\r\n<link href="/common/css/style.css?v=210721" rel="stylesheet">\r\n<link href="/common/cs
# ...

# %%
soup = BeautifulSoup(r.text, 'lxml')

# %%
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\nStarbucks Coffee Korea\n \n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n메뉴바로가기\n콘텐츠 바로가기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n님, 안녕하세요!\n개인정보 수정\n\n\n\n\n\n\n\n0\n\n\n\n\n\n\n\n\n스타벅스 리워드혜택에 편리함까지 더한스타벅스 리워드를즐겨보세요. \n\n\n\n\n\n\n\n\n\n\n잔액 0원\n\n다른 카드 보기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n잔액 원\n\n다른 카드 보기\n\n\n\n\n\n\n\n\n스타벅스 카드 등록카드를 등록하시고다양한 리워드를만나보세요.\n\n\n\n\n\n\n\n\n\n\n\n\n캘린더\n\n\n\n\n\n0\n\ne-쿠폰\n\n\n\n\n\n\ne-프리퀀시바코드\n\n\n\n\n\n\n\n\n\n스타벅스커피 코리아 회원이 아니세요?스타벅스커피 코리아 회원만의특별한 혜택을 누릴 수 있습니다.\n\n\n로그인\n회원가입\n\n\n\n\n\n\n스타벅스 카드를 가지고 계신가요?스타벅스 카드를 등록하시면, 스타벅스 리워드 만의특별한 혜택을 누릴 수 있습니다. \n\n카드 등록\n\n\n\n\n스타벅스 카드가 없으신가요?스타벅스 매장에서 구매하시거나,PC/모바일웹, 스타벅스 앱에서e-Gift를 “나에게 선물하기”로 구매 후,편리하게 등록하세요!스타벅스 리워드의 특별한 혜택! 생일 쿠폰을 드립니다!\n\ne-Gift 선물하기\n\n\n\n\n\n\n\n\n\n스타벅스 코리아\n\n\n\n마이스타벅스\n매장찾기\n메뉴열기\n\n\n\n\n\n\n\n\n닫기\n\n\n검색어\n\nSearch\n\n\n\n\nMy Starbucks\n한눈에 보기\n\nMy 리워드\n\n리워드 및 혜택\n별 히스토리\n\n\n\nMy 스타벅스 카드\n\n보유 카드\n카드 등록\n카드 충전\n분실신고/잔액이전\n\n\n\nMy 스타벅스 e-G
# ...

# %%
soup.find({'class' :'result_list scrollbar-inner mCustomScrollbar _mCS_3'})
