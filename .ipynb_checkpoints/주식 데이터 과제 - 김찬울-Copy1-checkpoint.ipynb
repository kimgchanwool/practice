# %%
import sqlalchemy
import requests
import pandas as pd
import pymysql

# %% [markdown]
# # 과제

# %% [markdown]
# stock.to_sql(name='daebak_jongmok', con=engine, if_exists='append', index=False)

# %% [markdown]
# 대상 : 2585 종목
#
# table 명 : deabak_jongmok
#
# 컬럼 : code, code_name, date, close, before, open, high, low, trade, ma05, ma20, ma60, ma120
#
# 기간 : 네이버 수집시 page 100페이지
#
# 주의사항 : NA 삭제, 중복 허용 X

# %% [markdown]
# ISU_CD	ISU_SRT_CD	ISU_NM	ISU_ABBRV	ISU_ENG_NM	LIST_DD	MKT_TP_NM	SECUGRP_NM	SECT_TP_NM	KIND_STKCERT_TP_NM	PARVAL	LIST_SHRS

# %% [markdown]
# date	close	before	open	high	low	trade	요일

# %% [markdown]
# # 주식 데이터

# %%
url_post = 'http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd'
head = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36"}
payload = {'bld': 'dbms/MDC/STAT/standard/MDCSTAT01901',
'mktId': 'ALL',
'share': '1',
'csvxls_isNo': 'false'}

r2 = requests.post(url_post, headers=head, data=payload)

r2.json()['OutBlock_1'] #딕셔너리는 데이터프레임으로 만들 수 있음

master = pd.DataFrame(r2.json()['OutBlock_1'])

# %% [markdown]
# # 최종 코드

# %%
stock_url = "https://finance.naver.com/item/sise_day.naver?code={}&page={}"
head = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36"}
total = []

for i, code in enumerate(master.values[:100]):
    if i % 10 == 0:
        print(f'{i}번째 데이터를 불러오고 있습니다...')
    try:
        nows = []
        for x in range(1, 13):
            r = requests.get(stock_url.format(code[1], x), headers=head)
            now_code = pd.DataFrame(code.reshape(1, 12), columns=['~', 'code', 'code_name', '~', '~', 'date', '~', '~', '~' ,'~', '~', '~'])[['code' ,'code_name']]
            now = pd.read_html(r.text)[0].dropna()
            now['code'] = now_code.code.to_list()[0]
            now['code_name'] = now_code.code_name.to_list()[0]
            nows.append(now)
        df1 = pd.concat(nows)
        df1 = df1.sort_values(by='날짜')
        df1['ma05'] = df1.종가.rolling(5).mean()
        df1['ma20'] = df1.종가.rolling(20).mean()
        df1['ma60'] = df1.종가.rolling(60).mean()
        df1['ma120'] = df1.종가.rolling(120).mean()
        total.append(df1.iloc[-1:])
    except:
        print('error')
daebak = pd.concat(total)
daebak.columns = ['date', 'close', 'before', 'open', 'high', 'low', 'trade', 'code', 'code_name', 'ma05', 'ma20', 'ma60', 'ma120']
daebak
# Out:
# 0번째 데이터를 불러오고 있습니다...
# 10번째 데이터를 불러오고 있습니다...
# 20번째 데이터를 불러오고 있습니다...
# 30번째 데이터를 불러오고 있습니다...
# 40번째 데이터를 불러오고 있습니다...
# 50번째 데이터를 불러오고 있습니다...
# 60번째 데이터를 불러오고 있습니다...
# 70번째 데이터를 불러오고 있습니다...
# 80번째 데이터를 불러오고 있습니다...
# 90번째 데이터를 불러오고 있습니다...
#           date     close  before      open      high       low     trade  \
# 1   2021.10.08    7550.0   230.0    7900.0    7970.0    7480.0   35594.0
# 1   2021.10.08     877.0    13.0     902.0     902.0     850.0  221995.0
# 1   2021.10.08    7170.0    30.0    7210.0    7360.0    7160.0  259913.0
# 1   2021.10.08    5690.0    20.0    5790.0    5790.0    5630.0  124442.0
# 1   2021.10.08   26300.0   100.0   26350.0   26850.0   25950.0   13340.0
# ..         ...       ...     ...       ...       ...       ...       ...
# 1   2021.10.08    4590.0   145.0    4455.0    4650.0    4420.0   48278.0
# 1   2021.10.08    3520.0     5.0    3630.0    3630.0    3515.0   24422.0
# 1   2021.10.08  230500.0   500.0  235000.0  235000.0  228500.0    1461.0
# 1   2021.10.08  157500.0  3000.0  158000.0  162000.0  155500.0  529266.0
# 1   2021.10.08  145500.0  2500.0  150000.0  150500.0  143500.0   31293.0
#
#       code     code_name      ma05       ma20           ma60          ma120
# 1   098120  (주)마이크로컨텍솔루션    7590.0    8479.00    8695.333333    7729.416667
# 1   131100     (주)스카이이앤엠     887.8     956.95    1198.283333    1404.100000
# 1   009520      (주)포스코엠텍    7342.0    7878.00    8315.833333    8715.916667
# 1   095570     AJ네트웍스보통주    5666.0    5898.50    5999.333333    5864.208333
# 1   006840      AK홀딩스보통주   26610.0   27087.50   27355.833333   29984.583333
# ..     ...           ...       ...        ...            ...            ...
# 1   123700        SJM보통주    4413.0    4655.75    4964.583333    5248.791667
# 1   025530     SJM홀딩스보통주    3524.0    3809.50    4194.583333    4422.000000
# 1   03473K        SK1우선주  232200.0  241375.00  244833.333333  250233.333333
# 1   011790        SKC보통주  159400.0  171450.00  163333.333333  152270.833333
# 1   018670       SK가스보통주  149100.0  155725.00  129658.333333  120745.833333
#
# [100 rows x 13 columns]

# %%
daebak.iloc[1,:]
# Out:
# date          2021.10.08
# close              877.0
# before              13.0
# open               902.0
# high               902.0
# low                850.0
# trade           221995.0
# code              131100
# code_name      (주)스카이이앤엠
# ma05               887.8
# ma20              956.95
# ma60         1198.283333
# ma120             1404.1
# Name: 1, dtype: object

# %%
import pymysql
try:
    con = pymysql.connect(host='3.34.134.218', user='root', port=3306, password='1234',  
                          db='daebak_jongmok', charset='utf8')
    cur = con.cursor()
except Exception as e:
    print (e)

# %%
engine = sqlalchemy.create_engine("mysql+mysqldb://root:" + "1234" + "@3.34.134.218/stocks", encoding='utf8')
stock.to_sql(name='daebak_jongmok', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-238-1850a3487a70> in <module>
#       1 engine = sqlalchemy.create_engine("mysql+mysqldb://root:" + "1234" + "@3.34.134.218/stocks", encoding='utf8')
# ----> 2 stock.to_sql(name='daebak_jongmok', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1409
#    1410         try:
# -> 1411             table.insert(chunksize, method=method)
#    1412         except exc.SQLAlchemyError as err:
#    1413             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     843
#     844                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845                 exec_insert(conn, keys, chunk_iter)
#     846
#     847     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     760         """
#     761         data = [dict(zip(keys, row)) for row in data_iter]
# --> 762         conn.execute(self.table.insert(), data)
#     763
#     764     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1198             )
#    1199         else:
# -> 1200             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1201
#    1202     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1931                 )
#    1932             else:
# -> 1933                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1934
#    1935         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1683                             break
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#    1687                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     146
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#     150             context._rowcount = rowcount
#
# ~\anaconda3\lib\site-packages\MySQLdb\cursors.py in executemany(self, query, args)
#     228             q_postfix = m.group(3) or ""
#     229             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 230             return self._do_execute_many(
#     231                 q_prefix,
#     232                 q_values,
#
# ~\anaconda3\lib\site-packages\MySQLdb\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     246         escape = self._escape_args
#     247         if isinstance(prefix, str):
# --> 248             prefix = prefix.encode(encoding)
#     249         if isinstance(values, str):
#     250             values = values.encode(encoding)
#
# ~\anaconda3\lib\encodings\cp1252.py in encode(self, input, errors)
#      10
#      11     def encode(self,input,errors='strict'):
# ---> 12         return codecs.charmap_encode(input,errors,encoding_table)
#      13
#      14     def decode(self,input,errors='strict'):
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 76-77: character maps to <undefined>

# %%
master
# Out:
#             ISU_CD ISU_SRT_CD            ISU_NM ISU_ABBRV  \
# 0     KR7098120009     098120      (주)마이크로컨텍솔루션   마이크로컨텍솔
# 1     KR7131100000     131100         (주)스카이이앤엠    스카이이앤엠
# 2     KR7009520008     009520          (주)포스코엠텍     포스코엠텍
# 3     KR7095570008     095570         AJ네트웍스보통주    AJ네트웍스
# 4     KR7006840003     006840          AK홀딩스보통주     AK홀딩스
# ...            ...        ...               ...       ...
# 2580  KR7000542001     000547  흥국화재해상보험2우선주(신형)   흥국화재2우B
# 2581  KR7000540005     000540       흥국화재해상보험보통주      흥국화재
# 2582  KR7003280005     003280           흥아해운보통주      흥아해운
# 2583  KR7037440005     037440        희림종합건축사사무소        희림
# 2584  KR7238490007     238490                힘스        힘스
#
#                            ISU_ENG_NM     LIST_DD MKT_TP_NM SECUGRP_NM  \
# 0     Micro Contact Solution Co.,Ltd.  2008/09/23    KOSDAQ         주권
# 1                   SKY E&M Co., Ltd.  2011/06/14    KOSDAQ         주권
# 2               POSCO M-TECH CO.,LTD.  1997/11/10    KOSDAQ         주권
# 3                AJ Networks Co.,Ltd.  2015/08/21     KOSPI         주권
# 4                   AK Holdings, Inc.  1999/08/11     KOSPI         주권
# ...                               ...         ...       ...        ...
# 2580      HeungkukFire&MarineIns(2PB)  1999/08/09     KOSPI         주권
# 2581     HeungkukFire&MarineInsurance  1974/12/05     KOSPI         주권
# 2582                   HeungaShipping  1976/06/29     KOSPI         주권
# 2583     Heerim Architects & Planners  2000/02/03    KOSDAQ         주권
# 2584                   HIMS CO., LTD.  2017/07/20    KOSDAQ         주권
#
#        SECT_TP_NM KIND_STKCERT_TP_NM PARVAL    LIST_SHRS
# 0           벤처기업부                보통주    500    8,312,766
# 1     관리종목(소속부없음)                보통주    100   53,703,566
# 2           우량기업부                보통주    500   41,642,703
# 3                                보통주  1,000   46,822,295
# 4                                보통주  5,000   13,247,561
# ...           ...                ...    ...          ...
# 2580                           신형우선주  5,000      153,600
# 2581                             보통주  5,000   64,242,645
# 2582                             보통주    500  239,125,028
# 2583        중견기업부                보통주    500   13,922,475
# 2584        우량기업부                보통주    500   11,312,236
#
# [2585 rows x 12 columns]

# %% [markdown]
# # 시도 및 검증

# %%
df1 = pd.concat(total)
df1 = df1[df1['code_name'] == '(주)마이크로컨텍솔루션']
df1 = df1.sort_values(by='날짜')

df1['ma05'] = df1.종가.rolling(5).mean()
df1['ma20'] = df1.종가.rolling(20).mean()
df1['ma60'] = df1.종가.rolling(60).mean()
df1['ma120'] = df1.종가.rolling(120).mean()
df1.iloc[-1:]
# Out:
#            날짜      종가    전일비      시가      고가      저가      거래량    code  \
# 1  2021.10.08  7550.0  230.0  7900.0  7970.0  7480.0  35594.0  098120
#
#       code_name    ma05    ma20         ma60        ma120
# 1  (주)마이크로컨텍솔루션  7590.0  8479.0  8695.333333  7729.416667

# %%
datetime.now()
# Out:
# datetime.datetime(2021, 10, 11, 1, 39, 36, 790647)

# %%
df1.종가.rolling(5).mean()
# Out:
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5     7590.0
#        ...
# 9     6116.0
# 10    6162.0
# 11    6198.0
# 12    6192.0
# 13    6170.0
# Name: 종가, Length: 120, dtype: float64

# %%
now.columns = ['code', 'code_name', 'date', 'close', 'before', 'open', 'high', 'low', 'trade', 'ma05', 'ma20', 'ma60', 'ma120']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-5bbdbce4f8c3> in <module>
# ----> 1 now.columns = ['code', 'code_name', 'date', 'close', 'before', 'open', 'high', 'low', 'trade', 'ma05', 'ma20', 'ma60', 'ma120']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 9 elements, new values have 13 elements

# %%
now
# Out:
#             날짜      종가   전일비      시가      고가      저가        거래량
# 1   2021.04.28  1795.0  10.0  1810.0  1825.0  1770.0   713592.0
# 2   2021.04.27  1805.0   0.0  1825.0  1825.0  1765.0   570676.0
# 3   2021.04.26  1805.0  70.0  1740.0  1815.0  1705.0  1007158.0
# 4   2021.04.23  1735.0  10.0  1745.0  1770.0  1710.0   568109.0
# 5   2021.04.22  1745.0  20.0  1720.0  1775.0  1690.0   828614.0
# 9   2021.04.21  1725.0  55.0  1765.0  1765.0  1715.0   577617.0
# 10  2021.04.20  1780.0  45.0  1810.0  1810.0  1745.0  1021765.0
# 11  2021.04.19  1825.0  35.0  1850.0  1850.0  1805.0   603925.0
# 12  2021.04.16  1860.0   5.0  1865.0  1870.0  1805.0   611787.0
# 13  2021.04.15  1865.0   0.0  1835.0  1870.0  1805.0  1026185.0

# %%
now_code
# Out:
#      code  code_name
# 0  131100  (주)스카이이앤엠

# %%
now_code.code.to_list()
# Out:
# ['131100']

# %%
now['code'] = now_code.code.to_list()[0]
now['code_name'] = now_code.code_name.to_list()[0]

# %%
now
# Out:
#             날짜      종가   전일비      시가      고가      저가        거래량    code  \
# 1   2021.04.28  1795.0  10.0  1810.0  1825.0  1770.0   713592.0  131100
# 2   2021.04.27  1805.0   0.0  1825.0  1825.0  1765.0   570676.0  131100
# 3   2021.04.26  1805.0  70.0  1740.0  1815.0  1705.0  1007158.0  131100
# 4   2021.04.23  1735.0  10.0  1745.0  1770.0  1710.0   568109.0  131100
# 5   2021.04.22  1745.0  20.0  1720.0  1775.0  1690.0   828614.0  131100
# 9   2021.04.21  1725.0  55.0  1765.0  1765.0  1715.0   577617.0  131100
# 10  2021.04.20  1780.0  45.0  1810.0  1810.0  1745.0  1021765.0  131100
# 11  2021.04.19  1825.0  35.0  1850.0  1850.0  1805.0   603925.0  131100
# 12  2021.04.16  1860.0   5.0  1865.0  1870.0  1805.0   611787.0  131100
# 13  2021.04.15  1865.0   0.0  1835.0  1870.0  1805.0  1026185.0  131100
#
#     code_name
# 1   (주)스카이이앤엠
# 2   (주)스카이이앤엠
# 3   (주)스카이이앤엠
# 4   (주)스카이이앤엠
# 5   (주)스카이이앤엠
# 9   (주)스카이이앤엠
# 10  (주)스카이이앤엠
# 11  (주)스카이이앤엠
# 12  (주)스카이이앤엠
# 13  (주)스카이이앤엠

# %%
now_code.code.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-0d7402b2db5a> in <module>
# ----> 1 now_code.code.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
pd.DataFrame(code.reshape(1, 12), columns=['~', 'code', 'code_name', '~', '~', 'date', '~', '~', '~' ,'~', '~', '~'])[['code' ,'code_name', 'date']]
# Out:
#      code  code_name        date
# 0  131100  (주)스카이이앤엠  2011/06/14

# %%
code.reshape(1, 12)
# Out:
# array([['KR7131100000', '131100', '(주)스카이이앤엠', '스카이이앤엠',
#         'SKY E&M Co., Ltd.', '2011/06/14', 'KOSDAQ', '주권', '관리종목(소속부없음)',
#         '보통주', '100', '53,703,566']], dtype=object)

# %%
code
# Out:
# array(['KR7131100000', '131100', '(주)스카이이앤엠', '스카이이앤엠',
#        'SKY E&M Co., Ltd.', '2011/06/14', 'KOSDAQ', '주권', '관리종목(소속부없음)',
#        '보통주', '100', '53,703,566'], dtype=object)

# %%
pd.merge(now, code, how='outter',on='날짜')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-48f8fe0ddfb4> in <module>
# ----> 1 pd.merge(now, code, how='outter',on='날짜')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     597     ):
#     598         _left = _validate_operand(left)
# --> 599         _right = _validate_operand(right)
#     600         self.left = self.orig_left = _left
#     601         self.right = self.orig_right = _right
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in
#  13  2021.05.14  1710.0    5.0  1705.0  1740.0  1665.0   634090.0,
#              날짜      종가   전일비      시가      고가      저가       거래량
#  1   2021.05.13  1705.0  45.0  1720.0  1725.0  1675.0  625310.0
#  2   2021.05.12  1750.0   0.0  1750.0  1770.0  1705.0  513850.0
#  3   2021.05.11  1750.0   5.0  1755.0  1775.0  1720.0  519685.0
#  4   2021.05.10  1755.0  45.0  1710.0  1800.0  1705.0  749209.0
#  5   2021.05.07  1710.0   0.0  1710.0  1735.0  1700.0  296409.0
#  9   2021.05.06  1710.0  10.0  1670.0  1740.0  1670.0  340391.0
#  10  2021.05.04  1700.0   0.0  1685.0  1710.0  1605.0  868100.0
#  11  2021.05.03  1700.0  40.0  1700.0  1765.0  1690.0  567172.0
#  12  2021.04.30  1740.0  30.0  1785.0  1805.0  1715.0  687846.0
#  13  2021.04.29  1770.0  25.0  1795.0  1815.0  1760.0  432508.0,
#              날짜      종가   전일비      시가      고가      저가        거래량
#  1   2021.04.28  1795.0  10.0  1810.0  1825.0  1770.0   713592.0
#  2   2021.04.27  1805.0   0.0  1825.0  1825.0  1765.0   570676.0
#  3   2021.04.26  1805.0  70.0  1740.0  1815.0  1705.0  1007158.0
#  4   2021.04.23  1735.0  10.0  1745.0  1770.0  1710.0   568109.0
#  5   2021.04.22  1745.0  20.0  1720.0  1775.0  1690.0   828614.0
#  9   2021.04.21  1725.0  55.0  1765.0  1765.0  1715.0   577617.0
#  10  2021.04.20  1780.0  45.0  1810.0  1810.0  1745.0  1021765.0
#  11  2021.04.19  1825.0  35.0  1850.0  1850.0  1805.0   603925.0
#  12  2021.04.16  1860.0   5.0  1865.0  1870.0  1805.0   611787.0
#  13  2021.04.15  1865.0   0.0  1835.0  1870.0  1805.0  1026185.0]

# %%
jongmok = pd.concat(total)

# %%
from datetime import datetime

# %%
day = datetime.today().strftime("%Y.%m.%d")
day
# Out:
# '2021.10.08'

# %%
jongmok['날짜']
# Out:
# 1     2021.10.08
# 2     2021.10.07
# 3     2021.10.06
# 4     2021.10.05
# 5     2021.10.01
#          ...
# 9     2021.09.30
# 10    2021.09.29
# 11    2021.09.28
# 12    2021.09.27
# 13    2021.09.24
# Name: 날짜, Length: 25804, dtype: object

# %%
jongmok = jongmok[jongmok['날짜'] == '2021.10.08']
jongmok.head()

# %%
master

# %%
merge_outer = pd.merge(jongmok,master, how='inner',on='id')

# %%
master.iloc[:0,:].to_sql(name='day_stock', con=engine, if_exists='append', index=False)

# DB 접속 
try:
    con = pymysql.connect(host='3.34.134.218', user='root', port=3306, password='1234',  
                          db='daebak_jongmok', charset='utf8')
    cur = con.cursor()
except Exception as e:
    print (e)   
sql = 'INSERT INTO daebak_jongmok_stock VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'

cur.execute('desc daebak_jongmok')
#con.commit()

# %%
url = 'https://www.data.go.kr/data/15043376/openapi.do'

# %%
url ='http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson?serviceKey=WRvGBkn9UEtw%2BAsg0tYo210Etxvb1QEcAX%2BwfWvOxVGYJkh1CNZ%2FY4QFa0r7j4bhT4NjPu7z1i1ck8ZgsKMt2Q%3D%3D&pageNo=1&numOfRows=10&startCreateDt=20210310&endCreateDt=20210515'

# %%
head = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36"}

# %%
import urllib.request 
import json 
import pandas as pd 
from pandas.io.json import json_normalize
import requests

# %%
import requests

params ={'serviceKey': '서비스키', 'pageNo' : '1', 'numOfRows' : '10', 'startCreateDt' : '20200310', 'endCreateDt' : '20200315' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><accDefRate>1.421472325</accDefRate><accExamCnt>9319093</accExamCnt><accExamCompCnt>9219877</accExamCompCnt><careCnt>7892</careCnt><clearCnt>121270</clearCnt><createDt>2021-05-15 00:00:00.000</createDt><deathCnt>1896</deathCnt><decideCnt>131058</decideCnt><examCnt>99216</examCnt><resutlNegCnt>9088819</resutlNegCnt><seq>482</seq><stateDt>20210515</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.419288441</accDefRate><accExamCnt>9281290</accExamCnt><accExamCompCnt>9186082</accExamCompCnt><careCnt>8100</careCnt><clearCnt>120384</clearCnt><createDt>2021-05-14 00:00:00.000</createDt><deathCnt>1893</deathCnt><decideCnt>130377</decideCnt><examCnt>95208</examCnt><resutlNegCnt>9055705</resutlNegCnt><seq>481</seq><stateDt>20210514</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.416158717</accDefRate><accExamCnt>9241152</accExamCnt><accExamCompCnt>9153635</accExamCompCnt><careCnt>7847</careCnt><clearCnt>119892</clearCnt><createDt>2021-05-13 00:00:00.000</createDt><deathCnt>1891</deathCnt><decideCnt>129630</decideCnt><examCnt>87517</examCnt><resutlNegCnt>9024005</resutlNegCnt><seq>480</seq><stateDt>20210513</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.413966632</accDefRate><accExamCnt>9201538</accExamCnt><accExamCompCnt>9117259</accExamCompCnt><careCnt>7671</careCnt><clearCnt>119360</clearCnt><createDt>2021-05-12 00:00:00.000</createDt><deathCnt>1884</deathCnt><decideCnt>128915</decideCnt><examCnt>84279</examCnt><resutlNegCnt>8988344</resutlNegCnt><seq>479</seq><stateDt>20210512</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.412840025</accDefRate><accExamCnt>9164283</accExamCnt><accExamCompCnt>9079655</accExamCompCnt><careCnt>7696</careCnt><clearCnt>118706</clearCnt><createDt>2021-05-11 00:00:00.000</createDt><deathCnt>1879</deathCnt><decideCnt>128281</decideCnt><examCnt>84628</examCnt><resutlNegCnt>8951374</resutlNegCnt><seq>478</seq><stateDt>20210511</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.413605557</accDefRate><accExamCnt>9122058</accExamCnt><accExamCompCnt>9038660</accExamCompCnt><careCnt>8064</careCnt><clearCnt>117832</clearCnt><createDt>2021-05-10 00:00:00.000</createDt><deathCnt>1875</deathCnt><decideCnt>127771</decideCnt><examCnt>83398</examCnt><resutlNegCnt>8910889</resutlNegCnt><seq>477</seq><stateDt>20210510</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.410694676</accDefRate><accExamCnt>9105770</accExamCnt><accExamCompCnt>9024490</accExamCompCnt><careCnt>8023</careCnt><clearCnt>117411</clearCnt><createDt>2021-05-09 00:00:00.000</createDt><deathCnt>1874</deathCnt><decideCnt>127308</decideCnt><examCnt>81280</examCnt><resutlNegCnt>8897182</resutlNegCnt><seq>476</seq><stateDt>20210509</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.406562226</accDefRate><accExamCnt>9089165</accExamCnt><accExamCompCnt>9010906</accExamCompCnt><careCnt>8011</careCnt><clearCnt>116868</clearCnt><createDt>2021-05-08 00:00:00.000</createDt><deathCnt>1865</deathCnt><decideCnt>126744</decideCnt><examCnt>78259</examCnt><resutlNegCnt>8884162</resutlNegCnt><seq>475</seq><stateDt>20210508</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.404776863</accDefRate><accExamCnt>9051353</accExamCnt><accExamCompCnt>8972457</accExamCompCnt><careCnt>8175</careCnt><clearCnt>116008</clearCnt><createDt>2021-05-07 00:00:00.000</createDt><deathCnt>1860</deathCnt><decideCnt>126043</decideCnt><examCnt>78896</examCnt><resutlNegCnt>8846414</r ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# %%
import xml.etree.ElementTree as ET
from xml.etree.ElementTree import Element, dump, ElementTree

# %%
doc = ET.parse(response.content)
#root 노드 가져오기
root = doc.getroot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-b8f52e93fce4> in <module>
# ----> 1 doc = ET.parse(response.content)
#       2 #root 노드 가져오기
#       3 root = doc.getroot()
#
# ~\anaconda3\lib\xml\etree\ElementTree.py in parse(source, parser)
#    1200     """
#    1201     tree = ElementTree()
# -> 1202     tree.parse(source, parser)
#    1203     return tree
#    1204
#
# ~\anaconda3\lib\xml\etree\ElementTree.py in parse(self, source, parser)
#     582         close_source = False
#     583         if not hasattr(source, "read"):
# --> 584             source = open(source, "rb")
#     585             close_source = True
#     586         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><accDefRate>1.421472325</accDefRate><accExamCnt>9319093</accExamCnt><accExamCompCnt>9219877</accExamCompCnt><careCnt>7892</careCnt><clearCnt>121270</clearCnt><createDt>2021-05-15 00:00:00.000</createDt><deathCnt>1896</deathCnt><decideCnt>131058</decideCnt><examCnt>99216</examCnt><resutlNegCnt>9088819</resutlNegCnt><seq>482</seq><stateDt>20210515</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.419288441</accDefRate><accExamCnt>9281290</accExamCnt><accExamCompCnt>9186082</accExamCompCnt><careCnt>8100</careCnt><clearCnt>120384</clearCnt><createDt>2021-05-14 00:00:00.000</createDt><deathCnt>1893</deathCnt><decideCnt>130377</decideCnt><examCnt>95208</examCnt><resutlNegCnt>9055705</resutlNegCnt><seq>481</seq><stateDt>20210514</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.416158717</accDefRate><accExamCnt>9241152</accExamCnt><accExamCompCnt>9153635</accExamCompCnt><careCnt>7847</careCnt><clearCnt>119892</clearCnt><createDt>2021-05-13 00:00:00.000</createDt><deathCnt>1891</deathCnt><decideCnt>129630</decideCnt><examCnt>87517</examCnt><resutlNegCnt>9024005</resutlNegCnt><seq>480</seq><stateDt>20210513</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.413966632</accDefRate><accExamCnt>9201538</accExamCnt><accExamCompCnt>9117259</accExamCompCnt><careCnt>7671</careCnt><clearCnt>119360</clearCnt><createDt>2021-05-12 00:00:00.000</createDt><deathCnt>1884</deathCnt><decideCnt>128915</decideCnt><examCnt>84279</examCnt><resutlNegCnt>8988344</resutlNegCnt><seq>479</seq><stateDt>20210512</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.412840025</accDefRate><accExamCnt>9164283</accExamCnt><accExamCompCnt>9079655</accExamCompCnt><careCnt>7696</careCnt><clearCnt>118706</clearCnt><createDt>2021-05-11 00:00:00.000</createDt><deathCnt>1879</deathCnt><decideCnt>128281</decideCnt><examCnt>84628</examCnt><resutlNegCnt>8951374</resutlNegCnt><seq>478</seq><stateDt>20210511</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.413605557</accDefRate><accExamCnt>9122058</accExamCnt><accExamCompCnt>9038660</accExamCompCnt><careCnt>8064</careCnt><clearCnt>117832</clearCnt><createDt>2021-05-10 00:00:00.000</createDt><deathCnt>1875</deathCnt><decideCnt>127771</decideCnt><examCnt>83398</examCnt><resutlNegCnt>8910889</resutlNegCnt><seq>477</seq><stateDt>20210510</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.410694676</accDefRate><accExamCnt>9105770</accExamCnt><accExamCompCnt>9024490</accExamCompCnt><careCnt>8023</careCnt><clearCnt>117411</clearCnt><createDt>2021-05-09 00:00:00.000</createDt><deathCnt>1874</deathCnt><decideCnt>127308</decideCnt><examCnt>81280</examCnt><resutlNegCnt>8897182</resutlNegCnt><seq>476</seq><stateDt>20210509</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.406562226</accDefRate><accExamCnt>9089165</accExamCnt><accExamCompCnt>9010906</accExamCompCnt><careCnt>8011</careCnt><clearCnt>116868</clearCnt><createDt>2021-05-08 00:00:00.000</createDt><deathCnt>1865</deathCnt><decideCnt>126744</decideCnt><examCnt>78259</examCnt><resutlNegCnt>8884162</resutlNegCnt><seq>475</seq><stateDt>20210508</stateDt><stateTime>00:00</stateTime><updateDt>2021-10-07 10:30:51.51</updateDt></item><item><accDefRate>1.404776863</accDefRate><accExamCnt>9051353</accExamCnt><accExamCompCnt>8972457</accExamCompCnt><careCnt>8175</careCnt><clearCnt>116008</clearCnt><createDt>2021-05-07 00:00:00.000</createDt><deathCnt>1860</deathCnt><decideCnt>126043</de ...

# %%
soup.find_all('item')[0].text
# Out:
# '1.4214723259319093921987778921212702021-05-15 00:00:00.00018961310589921690888194822021051500:002021-10-07 10:30:51.51'
