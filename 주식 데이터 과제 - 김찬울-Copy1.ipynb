# %%
url ='http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson?serviceKey=WRvGBkn9UEtw%2BAsg0tYo210Etxvb1QEcAX%2BwfWvOxVGYJkh1CNZ%2FY4QFa0r7j4bhT4NjPu7z1i1ck8ZgsKMt2Q%3D%3D&pageNo=1&numOfRows=10&startCreateDt=20210310&endCreateDt=20210515'

# %%
head = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36"}

# %%
import urllib.request 
import json 
import pandas as pd 
from pandas.io.json import json_normalize
import requests
import xml.etree.ElementTree as ET

# %%
#params ={'serviceKey': '서비스키', 'pageNo' : '1', 'numOfRows' : '10', 'startCreateDt' : '20200310', 'endCreateDt' : '20200315' }
r = requests.get(url)

root = ET.fromstring(r.text)

items = root.iter(tag='item')
total = []

for element in items:
    tmp_dict = dict()
    for x in element:
        tmp_dict[x.tag] = x.text
    total.append(tmp_dict)

# %%
total
# Out:
# [{'accDefRate': '1.421472325',
#   'accExamCnt': '9319093',
#   'accExamCompCnt': '9219877',
#   'careCnt': '7892',
#   'clearCnt': '121270',
#   'createDt': '2021-05-15 00:00:00.000',
#   'deathCnt': '1896',
#   'decideCnt': '131058',
#   'examCnt': '99216',
#   'resutlNegCnt': '9088819',
#   'seq': '482',
#   'stateDt': '20210515',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.419288441',
#   'accExamCnt': '9281290',
#   'accExamCompCnt': '9186082',
#   'careCnt': '8100',
#   'clearCnt': '120384',
#   'createDt': '2021-05-14 00:00:00.000',
#   'deathCnt': '1893',
#   'decideCnt': '130377',
#   'examCnt': '95208',
#   'resutlNegCnt': '9055705',
#   'seq': '481',
#   'stateDt': '20210514',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.416158717',
#   'accExamCnt': '9241152',
#   'accExamCompCnt': '9153635',
#   'careCnt': '7847',
#   'clearCnt': '119892',
#   'createDt': '2021-05-13 00:00:00.000',
#   'deathCnt': '1891',
#   'decideCnt': '129630',
#   'examCnt': '87517',
#   'resutlNegCnt': '9024005',
#   'seq': '480',
#   'stateDt': '20210513',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.413966632',
#   'accExamCnt': '9201538',
#   'accExamCompCnt': '9117259',
#   'careCnt': '7671',
#   'clearCnt': '119360',
#   'createDt': '2021-05-12 00:00:00.000',
#   'deathCnt': '1884',
#   'decideCnt': '128915',
#   'examCnt': '84279',
#   'resutlNegCnt': '8988344',
#   'seq': '479',
#   'stateDt': '20210512',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.412840025',
#   'accExamCnt': '9164283',
#   'accExamCompCnt': '9079655',
#   'careCnt': '7696',
#   'clearCnt': '118706',
#   'createDt': '2021-05-11 00:00:00.000',
#   'deathCnt': '1879',
#   'decideCnt': '128281',
#   'examCnt': '84628',
#   'resutlNegCnt': '8951374',
#   'seq': '478',
#   'stateDt': '20210511',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.413605557',
#   'accExamCnt': '9122058',
#   'accExamCompCnt': '9038660',
#   'careCnt': '8064',
#   'clearCnt': '117832',
#   'createDt': '2021-05-10 00:00:00.000',
#   'deathCnt': '1875',
#   'decideCnt': '127771',
#   'examCnt': '83398',
#   'resutlNegCnt': '8910889',
#   'seq': '477',
#   'stateDt': '20210510',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.410694676',
#   'accExamCnt': '9105770',
#   'accExamCompCnt': '9024490',
#   'careCnt': '8023',
#   'clearCnt': '117411',
#   'createDt': '2021-05-09 00:00:00.000',
#   'deathCnt': '1874',
#   'decideCnt': '127308',
#   'examCnt': '81280',
#   'resutlNegCnt': '8897182',
#   'seq': '476',
#   'stateDt': '20210509',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.406562226',
#   'accExamCnt': '9089165',
#   'accExamCompCnt': '9010906',
#   'careCnt': '8011',
#   'clearCnt': '116868',
#   'createDt': '2021-05-08 00:00:00.000',
#   'deathCnt': '1865',
#   'decideCnt': '126744',
#   'examCnt': '78259',
#   'resutlNegCnt': '8884162',
#   'seq': '475',
#   'stateDt': '20210508',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.404776863',
#   'accExamCnt': '9051353',
#   'accExamCompCnt': '8972457',
#   'careCnt': '8175',
#   'clearCnt': '116008',
#   'createDt': '2021-05-07 00:00:00.000',
#   'deathCnt': '1860',
#   'decideCnt': '126043',
#   'examCnt': '78896',
#   'resutlNegCnt': '8846414',
#   'seq': '474',
#   'stateDt': '20210507',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.404957457',
#   'accExamCnt': '9010991',
#   'accExamCompCnt': '8933936',
#   'careCnt': '8190',
#   'clearCnt': '115477',
#   'createDt': '2021-05-06 00:00:00.000',
#   'deathCnt': '1851',
#   'decideCnt': '125518',
#   'examCnt': '77055',
#   'resutlNegCnt': '8808418',
#   'seq': '473',
#   'stateDt': '20210506',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.401491609',
#   'accExamCnt': '8994068',
#   'accExamCompCnt': '8915073',
#   'careCnt': '8166',
#   'clearCnt': '114931',
#   'createDt': '2021-05-05 00:00:00.000',
#   'deathCnt': '1847',
#   'decideCnt': '124944',
#   'examCnt': '78995',
#   'resutlNegCnt': '8790129',
#   'seq': '472',
#   'stateDt': '20210505',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.399562882',
#   'accExamCnt': '8957154',
#   'accExamCompCnt': '8879058',
#   'careCnt': '8313',
#   'clearCnt': '114115',
#   'createDt': '2021-05-04 00:00:00.000',
#   'deathCnt': '1840',
#   'decideCnt': '124268',
#   'examCnt': '78096',
#   'resutlNegCnt': '8754790',
#   'seq': '471',
#   'stateDt': '20210504',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.401798692',
#   'accExamCnt': '8915325',
#   'accExamCompCnt': '8826303',
#   'careCnt': '8548',
#   'clearCnt': '113345',
#   'createDt': '2021-05-03 00:00:00.000',
#   'deathCnt': '1834',
#   'decideCnt': '123727',
#   'examCnt': '89022',
#   'resutlNegCnt': '8702576',
#   'seq': '470',
#   'stateDt': '20210503',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.398595447',
#   'accExamCnt': '8898233',
#   'accExamCompCnt': '8811626',
#   'careCnt': '8551',
#   'clearCnt': '112855',
#   'createDt': '2021-05-02 00:00:00.000',
#   'deathCnt': '1833',
#   'decideCnt': '123239',
#   'examCnt': '86607',
#   'resutlNegCnt': '8688387',
#   'seq': '469',
#   'stateDt': '20210502',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.393845883',
#   'accExamCnt': '8883387',
#   'accExamCompCnt': '8798175',
#   'careCnt': '8474',
#   'clearCnt': '112328',
#   'createDt': '2021-05-01 00:00:00.000',
#   'deathCnt': '1831',
#   'decideCnt': '122633',
#   'examCnt': '85212',
#   'resutlNegCnt': '8675542',
#   'seq': '468',
#   'stateDt': '20210501',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.391844194',
#   'accExamCnt': '8848291',
#   'accExamCompCnt': '8765780',
#   'careCnt': '8766',
#   'clearCnt': '111412',
#   'createDt': '2021-04-30 00:00:00.000',
#   'deathCnt': '1828',
#   'decideCnt': '122006',
#   'examCnt': '82511',
#   'resutlNegCnt': '8643774',
#   'seq': '467',
#   'stateDt': '20210430',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.390712113',
#   'accExamCnt': '8805778',
#   'accExamCompCnt': '8725386',
#   'careCnt': '8742',
#   'clearCnt': '110778',
#   'createDt': '2021-04-29 00:00:00.000',
#   'deathCnt': '1825',
#   'decideCnt': '121345',
#   'examCnt': '80392',
#   'resutlNegCnt': '8604041',
#   'seq': '466',
#   'stateDt': '20210429',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.388668632',
#   'accExamCnt': '8766496',
#   'accExamCompCnt': '8689330',
#   'careCnt': '8606',
#   'clearCnt': '110239',
#   'createDt': '2021-04-28 00:00:00.000',
#   'deathCnt': '1821',
#   'decideCnt': '120666',
#   'examCnt': '77166',
#   'resutlNegCnt': '8568664',
#   'seq': '465',
#   'stateDt': '20210428',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.386878116',
#   'accExamCnt': '8721608',
#   'accExamCompCnt': '8645100',
#   'careCnt': '8391',
#   'clearCnt': '109686',
#   'createDt': '2021-04-27 00:00:00.000',
#   'deathCnt': '1820',
#   'decideCnt': '119897',
#   'examCnt': '76508',
#   'resutlNegCnt': '8525203',
#   'seq': '464',
#   'stateDt': '20210427',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.389022528',
#   'accExamCnt': '8672977',
#   'accExamCompCnt': '8594893',
#   'careCnt': '8727',
#   'clearCnt': '108841',
#   'createDt': '2021-04-26 00:00:00.000',
#   'deathCnt': '1817',
#   'decideCnt': '119385',
#   'examCnt': '78084',
#   'resutlNegCnt': '8475508',
#   'seq': '463',
#   'stateDt': '20210426',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.386065198',
#   'accExamCnt': '8654790',
#   'accExamCompCnt': '8577230',
#   'careCnt': '8608',
#   'clearCnt': '108465',
#   'createDt': '2021-04-25 00:00:00.000',
#   'deathCnt': '1813',
#   'decideCnt': '118886',
#   'examCnt': '77560',
#   'resutlNegCnt': '8458344',
#   'seq': '462',
#   'stateDt': '20210425',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.382195163',
#   'accExamCnt': '8632922',
#   'accExamCompCnt': '8554653',
#   'careCnt': '8659',
#   'clearCnt': '107771',
#   'createDt': '2021-04-24 00:00:00.000',
#   'deathCnt': '1812',
#   'decideCnt': '118242',
#   'examCnt': '78269',
#   'resutlNegCnt': '8436411',
#   'seq': '461',
#   'stateDt': '20210424',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.374796777',
#   'accExamCnt': '8583529',
#   'accExamCompCnt': '8543590',
#   'careCnt': '8585',
#   'clearCnt': '107061',
#   'createDt': '2021-04-23 00:00:00.000',
#   'deathCnt': '1811',
#   'decideCnt': '117457',
#   'examCnt': '39939',
#   'resutlNegCnt': '8426133',
#   'seq': '460',
#   'stateDt': '20210423',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.377272408',
#   'accExamCnt': '8537504',
#   'accExamCompCnt': '8470365',
#   'careCnt': '8403',
#   'clearCnt': '106449',
#   'createDt': '2021-04-22 00:00:00.000',
#   'deathCnt': '1808',
#   'decideCnt': '116660',
#   'examCnt': '67139',
#   'resutlNegCnt': '8353705',
#   'seq': '459',
#   'stateDt': '20210422',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.375085969',
#   'accExamCnt': '8497593',
#   'accExamCompCnt': '8430382',
#   'careCnt': '8252',
#   'clearCnt': '105867',
#   'createDt': '2021-04-21 00:00:00.000',
#   'deathCnt': '1806',
#   'decideCnt': '115925',
#   'examCnt': '67211',
#   'resutlNegCnt': '8314457',
#   'seq': '458',
#   'stateDt': '20210421',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.372664279',
#   'accExamCnt': '8458591',
#   'accExamCompCnt': '8392001',
#   'careCnt': '8175',
#   'clearCnt': '105217',
#   'createDt': '2021-04-20 00:00:00.000',
#   'deathCnt': '1802',
#   'decideCnt': '115194',
#   'examCnt': '66590',
#   'resutlNegCnt': '8276807',
#   'seq': '457',
#   'stateDt': '20210420',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.373971918',
#   'accExamCnt': '8414820',
#   'accExamCompCnt': '8344057',
#   'careCnt': '8378',
#   'clearCnt': '104466',
#   'createDt': '2021-04-19 00:00:00.000',
#   'deathCnt': '1801',
#   'decideCnt': '114645',
#   'examCnt': '70763',
#   'resutlNegCnt': '8229412',
#   'seq': '456',
#   'stateDt': '20210419',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.37091215',
#   'accExamCnt': '8396065',
#   'accExamCompCnt': '8323874',
#   'careCnt': '8318',
#   'clearCnt': '103998',
#   'createDt': '2021-04-18 00:00:00.000',
#   'deathCnt': '1797',
#   'decideCnt': '114113',
#   'examCnt': '72191',
#   'resutlNegCnt': '8209761',
#   'seq': '455',
#   'stateDt': '20210418',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.365662265',
#   'accExamCnt': '8377778',
#   'accExamCompCnt': '8306739',
#   'careCnt': '8063',
#   'clearCnt': '103585',
#   'createDt': '2021-04-17 00:00:00.000',
#   'deathCnt': '1794',
#   'decideCnt': '113442',
#   'examCnt': '71039',
#   'resutlNegCnt': '8193297',
#   'seq': '454',
#   'stateDt': '20210417',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.365019181',
#   'accExamCnt': '8333331',
#   'accExamCompCnt': '8262448',
#   'careCnt': '7945',
#   'clearCnt': '103049',
#   'createDt': '2021-04-16 00:00:00.000',
#   'deathCnt': '1790',
#   'decideCnt': '112784',
#   'examCnt': '70883',
#   'resutlNegCnt': '8149664',
#   'seq': '453',
#   'stateDt': '20210416',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.363730967',
#   'accExamCnt': '8291124',
#   'accExamCompCnt': '8220903',
#   'careCnt': '7822',
#   'clearCnt': '102501',
#   'createDt': '2021-04-15 00:00:00.000',
#   'deathCnt': '1788',
#   'decideCnt': '112111',
#   'examCnt': '70221',
#   'resutlNegCnt': '8108792',
#   'seq': '452',
#   'stateDt': '20210415',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.363557535',
#   'accExamCnt': '8245386',
#   'accExamCompCnt': '8170759',
#   'careCnt': '7661',
#   'clearCnt': '101970',
#   'createDt': '2021-04-14 00:00:00.000',
#   'deathCnt': '1782',
#   'decideCnt': '111413',
#   'examCnt': '74627',
#   'resutlNegCnt': '8059346',
#   'seq': '451',
#   'stateDt': '20210414',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.36392993',
#   'accExamCnt': '8200517',
#   'accExamCompCnt': '8114933',
#   'careCnt': '7589',
#   'clearCnt': '101318',
#   'createDt': '2021-04-13 00:00:00.000',
#   'deathCnt': '1775',
#   'decideCnt': '110682',
#   'examCnt': '85584',
#   'resutlNegCnt': '8004251',
#   'seq': '450',
#   'stateDt': '20210413',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.366919627',
#   'accExamCnt': '8152781',
#   'accExamCompCnt': '8057533',
#   'careCnt': '7580',
#   'clearCnt': '100790',
#   'createDt': '2021-04-12 00:00:00.000',
#   'deathCnt': '1770',
#   'decideCnt': '110140',
#   'examCnt': '95248',
#   'resutlNegCnt': '7947393',
#   'seq': '449',
#   'stateDt': '20210412',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.363002809',
#   'accExamCnt': '8129530',
#   'accExamCompCnt': '8037621',
#   'careCnt': '7683',
#   'clearCnt': '100102',
#   'createDt': '2021-04-11 00:00:00.000',
#   'deathCnt': '1768',
#   'decideCnt': '109553',
#   'examCnt': '91909',
#   'resutlNegCnt': '7928068',
#   'seq': '448',
#   'stateDt': '20210411',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.358915373',
#   'accExamCnt': '8106628',
#   'accExamCompCnt': '8016614',
#   'careCnt': '7883',
#   'clearCnt': '99291',
#   'createDt': '2021-04-10 00:00:00.000',
#   'deathCnt': '1765',
#   'decideCnt': '108939',
#   'examCnt': '90014',
#   'resutlNegCnt': '7907675',
#   'seq': '447',
#   'stateDt': '20210410',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.357143027',
#   'accExamCnt': '8059111',
#   'accExamCompCnt': '7977199',
#   'careCnt': '7720',
#   'clearCnt': '98778',
#   'createDt': '2021-04-09 00:00:00.000',
#   'deathCnt': '1764',
#   'decideCnt': '108262',
#   'examCnt': '81912',
#   'resutlNegCnt': '7868937',
#   'seq': '446',
#   'stateDt': '20210409',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.356002483',
#   'accExamCnt': '8012419',
#   'accExamCompCnt': '7934425',
#   'careCnt': '7482',
#   'clearCnt': '98351',
#   'createDt': '2021-04-08 00:00:00.000',
#   'deathCnt': '1758',
#   'decideCnt': '107591',
#   'examCnt': '77994',
#   'resutlNegCnt': '7826834',
#   'seq': '445',
#   'stateDt': '20210408',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.354504067',
#   'accExamCnt': '7966165',
#   'accExamCompCnt': '7891523',
#   'careCnt': '7215',
#   'clearCnt': '97920',
#   'createDt': '2021-04-07 00:00:00.000',
#   'deathCnt': '1756',
#   'decideCnt': '106891',
#   'examCnt': '74642',
#   'resutlNegCnt': '7784632',
#   'seq': '444',
#   'stateDt': '20210407',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.354516686',
#   'accExamCnt': '7921288',
#   'accExamCompCnt': '7842133',
#   'careCnt': '7119',
#   'clearCnt': '97352',
#   'createDt': '2021-04-06 00:00:00.000',
#   'deathCnt': '1752',
#   'decideCnt': '106223',
#   'examCnt': '79155',
#   'resutlNegCnt': '7735910',
#   'seq': '443',
#   'stateDt': '20210406',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.35775092',
#   'accExamCnt': '7868818',
#   'accExamCompCnt': '7788321',
#   'careCnt': '7108',
#   'clearCnt': '96890',
#   'createDt': '2021-04-05 00:00:00.000',
#   'deathCnt': '1748',
#   'decideCnt': '105746',
#   'examCnt': '80497',
#   'resutlNegCnt': '7682575',
#   'seq': '442',
#   'stateDt': '20210405',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.354921538',
#   'accExamCnt': '7849474',
#   'accExamCompCnt': '7769675',
#   'careCnt': '6951',
#   'clearCnt': '96578',
#   'createDt': '2021-04-04 00:00:00.000',
#   'deathCnt': '1744',
#   'decideCnt': '105273',
#   'examCnt': '79799',
#   'resutlNegCnt': '7664402',
#   'seq': '441',
#   'stateDt': '20210404',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.350603555',
#   'accExamCnt': '7829599',
#   'accExamCompCnt': '7754311',
#   'careCnt': '6805',
#   'clearCnt': '96185',
#   'createDt': '2021-04-03 00:00:00.000',
#   'deathCnt': '1740',
#   'decideCnt': '104730',
#   'examCnt': '75288',
#   'resutlNegCnt': '7649581',
#   'seq': '440',
#   'stateDt': '20210403',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.350002546',
#   'accExamCnt': '7788293',
#   'accExamCompCnt': '7717541',
#   'careCnt': '6603',
#   'clearCnt': '95847',
#   'createDt': '2021-04-02 00:00:00.000',
#   'deathCnt': '1737',
#   'decideCnt': '104187',
#   'examCnt': '70752',
#   'resutlNegCnt': '7613354',
#   'seq': '439',
#   'stateDt': '20210402',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.349060526',
#   'accExamCnt': '7747301',
#   'accExamCompCnt': '7681642',
#   'careCnt': '6469',
#   'clearCnt': '95426',
#   'createDt': '2021-04-01 00:00:00.000',
#   'deathCnt': '1735',
#   'decideCnt': '103630',
#   'examCnt': '65659',
#   'resutlNegCnt': '7578012',
#   'seq': '438',
#   'stateDt': '20210401',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.349820651',
#   'accExamCnt': '7707798',
#   'accExamCompCnt': '7636496',
#   'careCnt': '6331',
#   'clearCnt': '95017',
#   'createDt': '2021-03-31 00:00:00.000',
#   'deathCnt': '1731',
#   'decideCnt': '103079',
#   'examCnt': '71302',
#   'resutlNegCnt': '7533417',
#   'seq': '437',
#   'stateDt': '20210331',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.352211626',
#   'accExamCnt': '7663997',
#   'accExamCompCnt': '7585573',
#   'careCnt': '6294',
#   'clearCnt': '94550',
#   'createDt': '2021-03-30 00:00:00.000',
#   'deathCnt': '1729',
#   'decideCnt': '102573',
#   'examCnt': '78424',
#   'resutlNegCnt': '7483000',
#   'seq': '436',
#   'stateDt': '20210330',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.354925246',
#   'accExamCnt': '7616328',
#   'accExamCompCnt': '7537390',
#   'careCnt': '6290',
#   'clearCnt': '94110',
#   'createDt': '2021-03-29 00:00:00.000',
#   'deathCnt': '1726',
#   'decideCnt': '102126',
#   'examCnt': '78938',
#   'resutlNegCnt': '7435264',
#   'seq': '435',
#   'stateDt': '20210329',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.353520672',
#   'accExamCnt': '7595594',
#   'accExamCompCnt': '7516989',
#   'careCnt': '6179',
#   'clearCnt': '93843',
#   'createDt': '2021-03-28 00:00:00.000',
#   'deathCnt': '1722',
#   'decideCnt': '101744',
#   'examCnt': '78605',
#   'resutlNegCnt': '7415245',
#   'seq': '434',
#   'stateDt': '20210328',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.350629659',
#   'accExamCnt': '7572566',
#   'accExamCompCnt': '7497392',
#   'careCnt': '6077',
#   'clearCnt': '93464',
#   'createDt': '2021-03-27 00:00:00.000',
#   'deathCnt': '1721',
#   'decideCnt': '101262',
#   'examCnt': '75174',
#   'resutlNegCnt': '7396130',
#   'seq': '433',
#   'stateDt': '20210327',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.35208143',
#   'accExamCnt': '7529401',
#   'accExamCompCnt': '7451992',
#   'careCnt': '6429',
#   'clearCnt': '92612',
#   'createDt': '2021-03-26 00:00:00.000',
#   'deathCnt': '1716',
#   'decideCnt': '100757',
#   'examCnt': '77409',
#   'resutlNegCnt': '7351235',
#   'seq': '432',
#   'stateDt': '20210326',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.355178997',
#   'accExamCnt': '7485858',
#   'accExamCompCnt': '7398875',
#   'careCnt': '6506',
#   'clearCnt': '92053',
#   'createDt': '2021-03-25 00:00:00.000',
#   'deathCnt': '1709',
#   'decideCnt': '100268',
#   'examCnt': '86983',
#   'resutlNegCnt': '7298607',
#   'seq': '431',
#   'stateDt': '20210325',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.358916428',
#   'accExamCnt': '7441209',
#   'accExamCompCnt': '7346883',
#   'careCnt': '6586',
#   'clearCnt': '91545',
#   'createDt': '2021-03-24 00:00:00.000',
#   'deathCnt': '1707',
#   'decideCnt': '99838',
#   'examCnt': '94326',
#   'resutlNegCnt': '7247045',
#   'seq': '430',
#   'stateDt': '20210324',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.361628431',
#   'accExamCnt': '7400989',
#   'accExamCompCnt': '7300817',
#   'careCnt': '6642',
#   'clearCnt': '91064',
#   'createDt': '2021-03-23 00:00:00.000',
#   'deathCnt': '1704',
#   'decideCnt': '99410',
#   'examCnt': '100172',
#   'resutlNegCnt': '7201407',
#   'seq': '429',
#   'stateDt': '20210323',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.365866653',
#   'accExamCnt': '7355963',
#   'accExamCompCnt': '7252831',
#   'careCnt': '6770',
#   'clearCnt': '90597',
#   'createDt': '2021-03-22 00:00:00.000',
#   'deathCnt': '1697',
#   'decideCnt': '99064',
#   'examCnt': '103132',
#   'resutlNegCnt': '7153767',
#   'seq': '428',
#   'stateDt': '20210322',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.363609032',
#   'accExamCnt': '7332713',
#   'accExamCompCnt': '7234405',
#   'careCnt': '6639',
#   'clearCnt': '90314',
#   'createDt': '2021-03-21 00:00:00.000',
#   'deathCnt': '1696',
#   'decideCnt': '98649',
#   'examCnt': '98308',
#   'resutlNegCnt': '7135756',
#   'seq': '427',
#   'stateDt': '20210321',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.36078075',
#   'accExamCnt': '7308949',
#   'accExamCompCnt': '7215931',
#   'careCnt': '6565',
#   'clearCnt': '89935',
#   'createDt': '2021-03-20 00:00:00.000',
#   'deathCnt': '1693',
#   'decideCnt': '98193',
#   'examCnt': '93018',
#   'resutlNegCnt': '7117738',
#   'seq': '426',
#   'stateDt': '20210320',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.362010055',
#   'accExamCnt': '7264940',
#   'accExamCompCnt': '7176599',
#   'careCnt': '6548',
#   'clearCnt': '89508',
#   'createDt': '2021-03-19 00:00:00.000',
#   'deathCnt': '1690',
#   'decideCnt': '97746',
#   'examCnt': '88341',
#   'resutlNegCnt': '7078853',
#   'seq': '425',
#   'stateDt': '20210319',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.364731094',
#   'accExamCnt': '7218086',
#   'accExamCompCnt': '7128364',
#   'careCnt': '6431',
#   'clearCnt': '89164',
#   'createDt': '2021-03-18 00:00:00.000',
#   'deathCnt': '1688',
#   'decideCnt': '97283',
#   'examCnt': '89722',
#   'resutlNegCnt': '7031081',
#   'seq': '424',
#   'stateDt': '20210318',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.366215546',
#   'accExamCnt': '7171509',
#   'accExamCompCnt': '7088047',
#   'careCnt': '6353',
#   'clearCnt': '88799',
#   'createDt': '2021-03-17 00:00:00.000',
#   'deathCnt': '1686',
#   'decideCnt': '96838',
#   'examCnt': '83462',
#   'resutlNegCnt': '6991209',
#   'seq': '423',
#   'stateDt': '20210317',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.367317856',
#   'accExamCnt': '7126076',
#   'accExamCompCnt': '7048032',
#   'careCnt': '6451',
#   'clearCnt': '88240',
#   'createDt': '2021-03-16 00:00:00.000',
#   'deathCnt': '1678',
#   'decideCnt': '96369',
#   'examCnt': '78044',
#   'resutlNegCnt': '6951663',
#   'seq': '422',
#   'stateDt': '20210316',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.368903786',
#   'accExamCnt': '7084939',
#   'accExamCompCnt': '7013349',
#   'careCnt': '6591',
#   'clearCnt': '87740',
#   'createDt': '2021-03-15 00:00:00.000',
#   'deathCnt': '1675',
#   'decideCnt': '96006',
#   'examCnt': '71590',
#   'resutlNegCnt': '6917343',
#   'seq': '421',
#   'stateDt': '20210315',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.366772257',
#   'accExamCnt': '7066400',
#   'accExamCompCnt': '6996557',
#   'careCnt': '6565',
#   'clearCnt': '87393',
#   'createDt': '2021-03-14 00:00:00.000',
#   'deathCnt': '1669',
#   'decideCnt': '95627',
#   'examCnt': '69843',
#   'resutlNegCnt': '6900930',
#   'seq': '420',
#   'stateDt': '20210314',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.36365193',
#   'accExamCnt': '7046781',
#   'accExamCompCnt': '6978907',
#   'careCnt': '6888',
#   'clearCnt': '86613',
#   'createDt': '2021-03-13 00:00:00.000',
#   'deathCnt': '1667',
#   'decideCnt': '95168',
#   'examCnt': '67874',
#   'resutlNegCnt': '6883739',
#   'seq': '419',
#   'stateDt': '20210313',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.363465187',
#   'accExamCnt': '7012663',
#   'accExamCompCnt': '6943925',
#   'careCnt': '7284',
#   'clearCnt': '85732',
#   'createDt': '2021-03-12 00:00:00.000',
#   'deathCnt': '1662',
#   'decideCnt': '94678',
#   'examCnt': '68738',
#   'resutlNegCnt': '6849247',
#   'seq': '418',
#   'stateDt': '20210312',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.363346349',
#   'accExamCnt': '6976984',
#   'accExamCompCnt': '6908736',
#   'careCnt': '7873',
#   'clearCnt': '84665',
#   'createDt': '2021-03-11 00:00:00.000',
#   'deathCnt': '1652',
#   'decideCnt': '94190',
#   'examCnt': '68248',
#   'resutlNegCnt': '6814546',
#   'seq': '417',
#   'stateDt': '20210311',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'accDefRate': '1.364541999',
#   'accExamCnt': '6938883',
#   'accExamCompCnt': '6868605',
#   'careCnt': '7776',
#   'clearCnt': '84301',
#   'createDt': '2021-03-10 00:00:00.000',
#   'deathCnt': '1648',
#   'decideCnt': '93725',
#   'examCnt': '70278',
#   'resutlNegCnt': '6774880',
#   'seq': '416',
#   'stateDt': '20210310',
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'}]

# %%
total[:][0]['stateDT']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-25c512833d04> in <module>
# ----> 1 total[:][0]['stateDT']
#
# KeyError: 'stateDT'

# %%
df = pd.DataFrame(total)

df['createDt'] = pd.to_datetime(df['createDt'])
df['stateDt'] = pd.to_datetime(df['stateDt'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   accDefRate      67 non-null     object
#  1   accExamCnt      67 non-null     object
#  2   accExamCompCnt  67 non-null     object
#  3   careCnt         67 non-null     object
#  4   clearCnt        67 non-null     object
#  5   createDt        67 non-null     datetime64[ns]
#  6   deathCnt        67 non-null     object
#  7   decideCnt       67 non-null     object
#  8   examCnt         67 non-null     object
#  9   resutlNegCnt    67 non-null     object
#  10  seq             67 non-null     object
#  11  stateDt         67 non-null     datetime64[ns]
#  12  stateTime       67 non-null     object
#  13  updateDt        67 non-null     object
# dtypes: datetime64[ns](2), object(12)
# memory usage: 7.5+ KB

# %%
df.isnull().sum()
# Out:
# accDefRate        0
# accExamCnt        0
# accExamCompCnt    0
# careCnt           0
# clearCnt          0
# createDt          0
# deathCnt          0
# decideCnt         0
# examCnt           0
# resutlNegCnt      0
# seq               0
# stateDt           0
# stateTime         0
# updateDt          0
# dtype: int64

# %%
df = df.sort_values(by=["stateDt"])

# %%
df[df.stateDt.duplicated()]
# Out:
# Empty DataFrame
# Columns: [accDefRate, accExamCnt, accExamCompCnt, careCnt, clearCnt, createDt, deathCnt, decideCnt, examCnt, resutlNegCnt, seq, stateDt, stateTime, updateDt]
# Index: []

# %%
df.query(''' stateDt >= "2020-10-01"''')
# Out:
#      accDefRate accExamCnt accExamCompCnt careCnt clearCnt   createDt  \
# 66  1.364541999    6938883        6868605    7776    84301 2021-03-10
# 65  1.363346349    6976984        6908736    7873    84665 2021-03-11
# 64  1.363465187    7012663        6943925    7284    85732 2021-03-12
# 63   1.36365193    7046781        6978907    6888    86613 2021-03-13
# 62  1.366772257    7066400        6996557    6565    87393 2021-03-14
# ..          ...        ...            ...     ...      ...        ...
# 4   1.412840025    9164283        9079655    7696   118706 2021-05-11
# 3   1.413966632    9201538        9117259    7671   119360 2021-05-12
# 2   1.416158717    9241152        9153635    7847   119892 2021-05-13
# 1   1.419288441    9281290        9186082    8100   120384 2021-05-14
# 0   1.421472325    9319093        9219877    7892   121270 2021-05-15
#
#    deathCnt decideCnt examCnt resutlNegCnt  seq    stateDt stateTime  \
# 66     1648     93725   70278      6774880  416 2021-03-10     00:00
# 65     1652     94190   68248      6814546  417 2021-03-11     00:00
# 64     1662     94678   68738      6849247  418 2021-03-12     00:00
# 63     1667     95168   67874      6883739  419 2021-03-13     00:00
# 62     1669     95627   69843      6900930  420 2021-03-14     00:00
# ..      ...       ...     ...          ...  ...        ...       ...
# 4      1879    128281   84628      8951374  478 2021-05-11     00:00
# 3      1884    128915   84279      8988344  479 2021-05-12     00:00
# 2      1891    129630   87517      9024005  480 2021-05-13     00:00
# 1      1893    130377   95208      9055705  481 2021-05-14     00:00
# 0      1896    131058   99216      9088819  482 2021-05-15     00:00
#
#                   updateDt
# 66  2021-10-07 10:30:51.51
# 65  2021-10-07 10:30:51.51
# 64  2021-10-07 10:30:51.51
# 63  2021-10-07 10:30:51.51
# 62  2021-10-07 10:30:51.51
# ..                     ...
# 4   2021-10-07 10:30:51.51
# 3   2021-10-07 10:30:51.51
# 2   2021-10-07 10:30:51.51
# 1   2021-10-07 10:30:51.51
# 0   2021-10-07 10:30:51.51
#
# [67 rows x 14 columns]

# %%
df['decideCnt'] = df['decideCnt'].astype(int)

# %%
df['today_Cnt'] =  df['decideCnt'] - df['decideCnt'].shift(1)

# %%
df.today_Cnt
# Out:
# 66      NaN
# 65    465.0
# 64    488.0
# 63    490.0
# 62    459.0
#       ...
# 4     510.0
# 3     634.0
# 2     715.0
# 1     747.0
# 0     681.0
# Name: today_Cnt, Length: 67, dtype: float64

# %%
df = df.sort_values(by=["stateDt"])
df['decideCnt'] = df['decideCnt'].astype(int)
df['today_Cnt'] =  df['decideCnt'] - df['decideCnt'].shift(1)

# %%
import numpy as np
type(np.NaN)
# Out:
# float

# %%
a, c = df[['today_Cnt', 'stateDt']], df['decideCnt'].iloc[-1]

# %%
df['decideCnt'].iloc[-1]
# Out:
# 131058

# %%
a
# Out:
#     today_Cnt    stateDt
# 66        NaN 2021-03-10
# 65      465.0 2021-03-11
# 64      488.0 2021-03-12
# 63      490.0 2021-03-13
# 62      459.0 2021-03-14
# ..        ...        ...
# 4       510.0 2021-05-11
# 3       634.0 2021-05-12
# 2       715.0 2021-05-13
# 1       747.0 2021-05-14
# 0       681.0 2021-05-15
#
# [67 rows x 2 columns]

# %%
c
# Out:
# 131058

# %%
a = [[12], [15]]

# %%
a[1][0]
# Out:
# 15

# %%
xs = [('005930', ['100']), ('000660', ['100000'])]

# %%
xs[0]
# Out:
# ('005930', ['100'])

# %%
xs[1]
# Out:
# ('000660', ['100000'])

# %%
aas = []
for x in xs:
    aas.append(x[0])

# %%
xs[:]
# Out:
# [('005930', ['100']), ('000660', ['100000'])]

# %%
aas
# Out:
# ['005930', '000660']

# %%
[['삼성전자', '005930', '70,200', '100', '+1.15%', '7,020,000'], ['SK하이닉스', '000660', '97,900', '100,000', '+4.37%', '9,790,000,000']]

# %%
df[['today_Cnt', 'stateDt']].dropna().values
# Out:
# array([[465.0, Timestamp('2021-03-11 00:00:00')],
#        [488.0, Timestamp('2021-03-12 00:00:00')],
#        [490.0, Timestamp('2021-03-13 00:00:00')],
#        [459.0, Timestamp('2021-03-14 00:00:00')],
#        [379.0, Timestamp('2021-03-15 00:00:00')],
#        [363.0, Timestamp('2021-03-16 00:00:00')],
#        [469.0, Timestamp('2021-03-17 00:00:00')],
#        [445.0, Timestamp('2021-03-18 00:00:00')],
#        [463.0, Timestamp('2021-03-19 00:00:00')],
#        [447.0, Timestamp('2021-03-20 00:00:00')],
#        [456.0, Timestamp('2021-03-21 00:00:00')],
#        [415.0, Timestamp('2021-03-22 00:00:00')],
#        [346.0, Timestamp('2021-03-23 00:00:00')],
#        [428.0, Timestamp('2021-03-24 00:00:00')],
#        [430.0, Timestamp('2021-03-25 00:00:00')],
#        [489.0, Timestamp('2021-03-26 00:00:00')],
#        [505.0, Timestamp('2021-03-27 00:00:00')],
#        [482.0, Timestamp('2021-03-28 00:00:00')],
#        [382.0, Timestamp('2021-03-29 00:00:00')],
#        [447.0, Timestamp('2021-03-30 00:00:00')],
#        [506.0, Timestamp('2021-03-31 00:00:00')],
#        [551.0, Timestamp('2021-04-01 00:00:00')],
#        [557.0, Timestamp('2021-04-02 00:00:00')],
#        [543.0, Timestamp('2021-04-03 00:00:00')],
#        [543.0, Timestamp('2021-04-04 00:00:00')],
#        [473.0, Timestamp('2021-04-05 00:00:00')],
#        [477.0, Timestamp('2021-04-06 00:00:00')],
#        [668.0, Timestamp('2021-04-07 00:00:00')],
#        [700.0, Timestamp('2021-04-08 00:00:00')],
#        [671.0, Timestamp('2021-04-09 00:00:00')],
#        [677.0, Timestamp('2021-04-10 00:00:00')],
#        [614.0, Timestamp('2021-04-11 00:00:00')],
#        [587.0, Timestamp('2021-04-12 00:00:00')],
#        [542.0, Timestamp('2021-04-13 00:00:00')],
#        [731.0, Timestamp('2021-04-14 00:00:00')],
#        [698.0, Timestamp('2021-04-15 00:00:00')],
#        [673.0, Timestamp('2021-04-16 00:00:00')],
#        [658.0, Timestamp('2021-04-17 00:00:00')],
#        [671.0, Timestamp('2021-04-18 00:00:00')],
#        [532.0, Timestamp('2021-04-19 00:00:00')],
#        [549.0, Timestamp('2021-04-20 00:00:00')],
#        [731.0, Timestamp('2021-04-21 00:00:00')],
#        [735.0, Timestamp('2021-04-22 00:00:00')],
#        [797.0, Timestamp('2021-04-23 00:00:00')],
#        [785.0, Timestamp('2021-04-24 00:00:00')],
#        [644.0, Timestamp('2021-04-25 00:00:00')],
#        [499.0, Timestamp('2021-04-26 00:00:00')],
#        [512.0, Timestamp('2021-04-27 00:00:00')],
#        [769.0, Timestamp('2021-04-28 00:00:00')],
#        [679.0, Timestamp('2021-04-29 00:00:00')],
#        [661.0, Timestamp('2021-04-30 00:00:00')],
#        [627.0, Timestamp('2021-05-01 00:00:00')],
#        [606.0, Timestamp('2021-05-02 00:00:00')],
#        [488.0, Timestamp('2021-05-03 00:00:00')],
#        [541.0, Timestamp('2021-05-04 00:00:00')],
#        [676.0, Timestamp('2021-05-05 00:00:00')],
#        [574.0, Timestamp('2021-05-06 00:00:00')],
#        [525.0, Timestamp('2021-05-07 00:00:00')],
#        [701.0, Timestamp('2021-05-08 00:00:00')],
#        [564.0, Timestamp('2021-05-09 00:00:00')],
#        [463.0, Timestamp('2021-05-10 00:00:00')],
#        [510.0, Timestamp('2021-05-11 00:00:00')],
#        [634.0, Timestamp('2021-05-12 00:00:00')],
#        [715.0, Timestamp('2021-05-13 00:00:00')],
#        [747.0, Timestamp('2021-05-14 00:00:00')],
#        [681.0, Timestamp('2021-05-15 00:00:00')]], dtype=object)
